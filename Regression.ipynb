# %%
import seaborn as sns
import pandas as pd

df = pd.DataFrame(data={
    'Metrekare' : [100,150,120,300,230],
    'Fiyat': [70,90,95,120,110]

})

df
# Out:
#    Metrekare  Fiyat
# 0        100     70
# 1        150     90
# 2        120     95
# 3        300    120
# 4        230    110

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

reg = LinearRegression().fit(X,y)

print(f"Score: {reg.score(X,y)}")
print(f"Coefficient: {reg.coef_}")
print(f"Intercept: {reg.intercept_}")

"""
y = wx+b

y : label
w : weight of x
X : feature
b : bias (Intercept)
"""
# Out:
# Score: 0.8460528874197938
# Coefficient: [0.21223022]
# Intercept: 58.79856115107912
# '\ny = wx+b\n\ny : label\nw : weight of x\nX : feature\nb : bias (Intercept)\n'

# %%
m2 = int(input("Please enter the label predict: "))
print(f"{m2} m2 home predict label: {reg.predict(np.array([[m2]]))}")
# Out:
# Please enter the label predict: 120
# 120 m2 home predict label: [84.26618705]
